# %%
import os
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
msft = yf.Ticker("MSFT")

# %%
#print(msft.info)

hist = msft.history(period="365d")
hist_df = pd.DataFrame(hist)
hist_df.to_pickle("")
print(hist_df)
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2019-03-28  115.31  115.44  114.02  114.81  18334800        0.0             0
# 2019-03-29  115.92  116.17  114.83  115.80  25399800        0.0             0
# 2019-04-01  116.79  116.95  115.95  116.86  22789100        0.0             0
# 2019-04-02  116.90  117.31  116.37  117.02  18142300        0.0             0
# 2019-04-03  117.68  118.24  116.98  117.79  22860700        0.0             0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-08-31  227.00  228.70  224.31  225.53  28774200        0.0             0
# 2020-09-01  225.51  227.45  224.43  227.27  25791200        0.0             0
# 2020-09-02  227.97  232.86  227.35  231.65  34080800        0.0             0
# 2020-09-03  229.27  229.31  214.96  217.30  58148900        0.0             0
# 2020-09-04  215.10  218.36  205.19  214.25  59664072        0.0             0
#
# [365 rows x 7 columns]

# %%
hist['Close'].plot(figsize=(16, 9))
# Out:
# <AxesSubplot:xlabel='Date'>
